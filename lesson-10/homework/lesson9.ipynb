# %%
# Task 1

import math

class Cicle:
    def __init__(self, radius):
        self.radius=radius

    def area(self):
        return math.pi*self.radius**2
    
    def perimetr(self):
        return 2*math.pi*self.radius
    
r=float(input("Enter the radius of the cicle: "))
Cicle=Cicle(r)

print("Area of the cicle:", Cicle.area())
print("Perimetr of the cicle:", Cicle.perimetr())
# Out:
# Area of the cicle: 12.566370614359172
# Perimetr of the cicle: 12.566370614359172

# %%
# Task 2

from datetime import datetime

class Person:
    def __init__(self, name, country, date_of_birth ):
        self.name=name
        self.country=country
         # Convert string input into a date object
        self.date_of_birth = datetime.strptime(date_of_birth, "%Y-%m-%d")

    def get_age(self):
        today=datetime.today()
        age=today.year-self.date_of_birth.year
        
          # Adjust if birthday hasn't occurred yet this year
        if (today.month, today.day) < (self.date_of_birth.month, self.date_of_birth.day):
            age -= 1

        return age
    
# Example usage:
name = input("Enter your name: ")
country = input("Enter your country: ")
dob = input("Enter your date of birth (YYYY-MM-DD): ")

person = Person(name, country, dob)

print(f"\nName: {person.name}")
print(f"Country: {person.country}")
print(f"Age: {person.get_age()} years")
# Out:
# Name: dff
# Country: sfff
# Age: 33 years

# %%
# Task 3

class Calculator:
    def add(self, a, b):
        return a + b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b == 0:
            return "Error: Division by zero is not allowed."
        return a / b


# Example usage:
calc = Calculator()

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", calc.add(a, b))
print("Multiplication:", calc.multiply(a, b))
print("Division:", calc.divide(a, b))
# Out:
# Addition: 11.0
# Multiplication: 30.0
# Division: 0.8333333333333334

# %%
# Task 4

# Base Class
class Shape:
    def area(self):
        raise NotImplementedError("Subclasses must implement this method.")
    
    def perimetr(self):
        raise NotImplementedError('Subclasses must implement this method.')
    
# cicle subclass

class Cicle(Shape):
    def __init__(self, radius):
        self.radius=radius

    def area(self):
        return math.pi * self.radius ** 2
    
    def perimetr(self):
         return 2 * math.pi * self.radius
    

# Square subclass

class Square(Shape):
    def __init__ (self, side):
        self.side=side

    def area(self):
        return self.side**2
    
    def perimetr(self):
         return 4 * self.side
    

# Triangle subclass (for simplicity, assume it's an equilateral triangle)
class Triangle(Shape):
    def __init__(self, side):
        self.side = side

    def area(self):
        # Area of equilateral triangle: (sqrt(3) / 4) * side^2
        return (math.sqrt(3) / 4) * self.side ** 2

    def perimeter(self):
        return 3 * self.side
    

shapes=[
    Cicle(radius=5),
    Square(side=4),
    Triangle(side=3)
]

for shape in shapes:
    print(f"\n{shape.__class__.__name__}")
    print("Area:", shape.area())
    print("Perimeter:", shape.perimeter())

# %%
# Task 5

class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


class BinarySearchTree:
    def __init__(self):
        self.root = None

    # Insert method
    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            self._insert_recursive(self.root, value)

    def _insert_recursive(self, current, value):
        if value < current.value:
            if current.left is None:
                current.left = Node(value)
            else:
                self._insert_recursive(current.left, value)
        elif value > current.value:
            if current.right is None:
                current.right = Node(value)
            else:
                self._insert_recursive(current.right, value)
        # If value already exists, do nothing (you could handle duplicates here)

    # Search method
    def search(self, value):
        return self._search_recursive(self.root, value)

    def _search_recursive(self, current, value):
        if current is None:
            return False
        if value == current.value:
            return True
        elif value < current.value:
            return self._search_recursive(current.left, value)
        else:
            return self._search_recursive(current.right, value)


# Example usage
bst = BinarySearchTree()
values_to_insert = [50, 30, 70, 20, 40, 60, 80]

for value in values_to_insert:
    bst.insert(value)

# Search for elements
search_values = [60, 25]

for val in search_values:
    found = bst.search(val)
    print(f"Search for {val}: {'Found' if found else 'Not Found'}")
# Out:
# Search for 60: Found
# Search for 25: Not Found

# %%
# Task 6

class Stack:
    def __init__(self):
        self.items=[]

    # Push an item onto the stack
    def push(self, item):
        self.items.append(item)

    # Pop the top item from the stack
    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return "Stack is empty"
        
    # View the top item without removing it
    def peek(self):
            if not self.is_empty():
               return self.items[-1]
            else:
               return "Stack is empty" 
            
    # Check if the stack is empty   
    def is_empty(self):    
        return len(self.items)==0
    
    # Return the size of the stack
    def size(self):
        return len(self.items)
    
    # Display the stack
    def display(self):
        print("Stack (top to bottom):", list(reversed(self.items)))


stack=Stack()

stack.push(10)
stack.push(20)
stack.push(30)
stack.display()

print("Popped:", stack.pop())
stack.display()

print("Top items:", stack.peek())
print("Is stack empty?", stack.is_empty())
print("Stack size:", stack.size())
# Out:
# Stack (top to bottom): [30, 20, 10]
# Popped: 30
# Stack (top to bottom): [20, 10]
# Top items: 20
# Is stack empty? False
# Stack size: 2

# %%
# Task 7

# Node class: represents a single node in the linked list
class Node:
    def __init__(self, data):
        self.data=data
        self.next=None

# LinkedList class: manages the list
class LinkedList:
    def __init__(self):
        self.head=None

    # Insert a new node at the end
    def insert(self, data):
        new_node=Node(data)
        if not self.head: #If list is empty
            self.head=new_node
        else:
            current=self.head
            while current.next:
                current=current.next
            current.next=new_node
        print(f"Inserted:  {data}")

    # Delete the first node with the given value
    def delete(self, data):
        current=self.head
        previous = None

        while current:
            if current.data == data:
                if previous is None:  # Deleting the head
                    self.head = current.next
                else:
                    previous.next = current.next
                print(f"Deleted: {data}")
                return
            previous = current
            current = current.next

        print(f"Value {data} not found in the list.")

    # Display the linked list
    def display(self):
        current = self.head
        if not current:
            print("Linked list is empty.")
            return

        print("Linked list:", end=" ")
        while current:
            print(current.data, end=" → ")
            current = current.next
        print("None")


# Example usage
ll = LinkedList()
ll.insert(10)
ll.insert(20)
ll.insert(30)
ll.display()

ll.delete(20)
ll.display()

ll.delete(40)
# Out:
# Inserted:  10
# Inserted:  20
# Inserted:  30
# Linked list: 10 → 20 → 30 → None
# Deleted: 20
# Linked list: 10 → 30 → None
# Value 40 not found in the list.

# %%
# Task 8

class ShoppingCart:
    def __init__(self):
        self.items=[]  # Each item is a dictionary: {"name": ..., "price": ...}

    def add_item(self, name, price):
        self.items.append({"name": name, "price": price })
        print(f"Added {name} - ${price:.2f}")

    def remove_item(self, name):
        for item in self.items:
            if item["name"]==name:
                self.items.remove(item)
                print(f"Removed {name}")
                return
        print(f"{name} not found in the cart")

    def calculate_total(self):
        total=sum(item["price"] for item in self.items)
        return total
    
    def display_cart(self):
        if not self.items:
            print("Your cart is empty")
        else:
            print("Items in your cart:")
            for item in self.items:
                print(f"- {item['name']}: ${item['price']:.2f}")
            print(f"Total: ${self.calculate_total():.2f}")


cart=ShoppingCart()

cart.add_item("Orange", 3.40)
cart.add_item("Pineapple", 5.40)
cart.add_item("Strawberry", 4.70)

cart.display_cart()

cart.remove_item("Orange")
cart.display_cart()
# Out:
# Added Orange - $3.40
# Added Pineapple - $5.40
# Added Strawberry - $4.70
# Items in your cart:
# - Orange: $3.40
# - Pineapple: $5.40
# - Strawberry: $4.70
# Total: $13.50
# Removed Orange
# Items in your cart:
# - Pineapple: $5.40
# - Strawberry: $4.70
# Total: $10.10

# %%
# Task 9

class Stack:
    def __init__(self):
        self.items = []

    # Add item to the top of the stack
    def push(self, item):
        self.items.append(item)
        print(f"Pushed: {item}")

    # Remove and return the top item of the stack
    def pop(self):
        if not self.is_empty():
            popped_item = self.items.pop()
            print(f"Popped: {popped_item}")
            return popped_item
        else:
            print("Stack is empty. Nothing to pop.")
            return None

    # Display the stack from top to bottom
    def display(self):
        if not self.is_empty():
            print("Stack (top to bottom):")
            for item in reversed(self.items):
                print(item)
        else:
            print("Stack is empty.")

    # Check if the stack is empty
    def is_empty(self):
        return len(self.items) == 0


# Example usage
stack = Stack()

stack.push(10)
stack.push(20)
stack.push(30)
stack.display()

stack.pop()
stack.display()
# Out:
# Pushed: 10
# Pushed: 20
# Pushed: 30
# Stack (top to bottom):
# 30
# 20
# 10
# Popped: 30
# Stack (top to bottom):
# 20
# 10

# %%
# Task 10

class Queue:
    def __init__(self):
        self.items=[]

    # Add item to the end of the queue
    def enqueue(self, item):
        self.items.append(item)
        print(f"Enqueue: {item}")

     # Remove item from the front of the queue
    def dequeue(self):
        if not self.is_empty():
            removed=self.items.pop(0)
            print(f"Dequeue: {removed}")
            return removed
        else:
            print("Queue is empty")
            return None
        
    # Check if the queue is empty
    def is_empty(self):
        return len(self.items)==0
    
     # Display the queue

    def display(self):
        if self.is_empty():
            print("Queue is empty")
        else:
            print("Queue:", self.items)

# Example usage
q=Queue()

q.enqueue(10)
q.enqueue(20)
q.enqueue(30)
q.display()

q.dequeue()
q.display()
# Out:
# Enqueue: 10
# Enqueue: 20
# Enqueue: 30
# Queue: [10, 20, 30]
# Dequeue: 10
# Queue: [20, 30]

# %%
# Task 11

class Bank:
    def __init__(self, name):
        self.name = name
        self.balance = 0

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} deposited. New balance: {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds.")
        else:
            self.balance -= amount
            print(f"{amount} withdrawn. New balance: {self.balance}")

    def check_balance(self):
        print(f"Current balance: {self.balance}")


# Example usage:
customer1 = Bank("Alice")

customer1.deposit(500)
customer1.withdraw(200)
customer1.check_balance()
# Out:
# 500 deposited. New balance: 500
# 200 withdrawn. New balance: 300
# Current balance: 300
